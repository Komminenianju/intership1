# %% [markdown]
# <a href="https://colab.research.google.com/github/Komminenianju/intership1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Generate 2D data
np.random.seed(0)
x=np.random.randn(100,2)
y=(x[:,0]+x[:,1]>0).astype(int)

model=LogisticRegression()
model.fit(x,y)

plt.scatter(x[:,0],x[:,1],c=y,cmap='bwr',edgecolors='k')

w=model.coef_[0]
b=model.intercept_[0]
x_vals=np.linspace(-3,3,100)
y_vals=-(w[0]*x_vals+b)/w[1]

plt.plot(x_vals,y_vals,'k--')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()
